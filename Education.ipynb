# %%
import pandas as pd
import numpy as np
import plotly.express as px

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("educational-facilities-in-nigeria (1).csv", low_memory=False)
df
# Out:
#                            facility_name  \
# 0                              CPS SWALI
# 1                     NANA Basic Academy
# 2            L.E.A Primary School Pabeyi
# 3             L.E.A.PrimarySchoolPagadna
# 4                        Syflora Academy
# ...                                  ...
# 98662             Liberty Primary School
# 98663              Anfani Primary School
# 98664               OLUMAWU BASIC SCHOOL
# 98665                   UBE Akudu Karreh
# 98666  Government Pry School Efut Ibonda
#
#                               facility_type_display improved_water_supply  \
# 0                               Primary school only                  True
# 1      Primary and Junior Secondary school combined                 False
# 2                               Primary school only                  True
# 3                               Primary school only                 False
# 4                               Primary school only                 False
# ...

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'facility_id',
#        'community', 'ward', 'management', 'sector', 'formhub_photo_id', 'gps',
#        'survey_id', 'unique_lga', 'latitude', 'longitude'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 98667 entries, 0 to 98666
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   facility_name                 98452 non-null  str
#  1   facility_type_display         97764 non-null  str
#  2   improved_water_supply         98388 non-null  object
#  3   improved_sanitation           98370 non-null  object
#  4   chalkboard_each_classroom_yn  96506 non-null  object
#  5   num_tchrs_with_nce            95137 non-null  float64
#  6   num_tchr_full_time            96503 non-null  float64
#  7   num_students_total            93405 non-null  float64
#  8   num_classrms_total            95375 non-null  float64
#  9   phcn_electricity              98390 non-null  object
#  10  num_toilets_total             95705 non-null  float64
#  11  num_students_male             94292 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# facility_name                    215
# facility_type_display            903
# improved_water_supply            279
# improved_sanitation              297
# chalkboard_each_classroom_yn    2161
# num_tchrs_with_nce              3530
# num_tchr_full_time              2164
# num_students_total              5262
# num_classrms_total              3292
# phcn_electricity                 277
# num_toilets_total               2962
# num_students_male               4375
# num_students_female             4346
# num_tchrs_male                  3680
# num_tchrs_female                3319
# date_of_survey                     0
# education_type                   221
# facility_id                        0
# community                        238
# ward                             771
# management                      1223
# sector                             0
# formhub_photo_id                   0
# gps                                0
# survey_id                          0
# ...

# %%
 df.describe()
# Out:
#        num_tchrs_with_nce  num_tchr_full_time  num_students_total  \
# count        95137.000000        96503.000000        93405.000000
# mean             7.017922           11.666197          335.406306
# std              8.045479           14.033793          343.354223
# min              0.000000            0.000000            0.000000
# 25%              2.000000            4.000000          118.000000
# 50%              5.000000            8.000000          223.000000
# 75%              9.000000           14.000000          419.000000
# max            100.000000          899.000000         2355.000000
#
#        num_classrms_total  num_toilets_total  num_students_male  \
# count        95375.000000       95705.000000       94292.000000
# mean             8.443512           2.546722         187.804628
# std              7.110507           5.768857         257.891030
# min              0.000000           0.000000           0.000000
# ...

# %%
df.duplicated(subset='facility_id').sum()
# Out:
# np.int64(53)

# %%
df = df.drop_duplicates(subset='facility_id')
df.duplicated(subset='facility_id').sum()
# Out:
# np.int64(0)

# %%
df.drop(columns = {
    'formhub_photo_id',
    'gps',
    'survey_id',
    'facility_id'
}, inplace=True)
df.head()
# Out:
#                  facility_name                         facility_type_display  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
#
#   improved_water_supply improved_sanitation chalkboard_each_classroom_yn  \
# 0                  True                True                        False
# 1                 False               False                          NaN
# 2                  True                True                        False
# 3                 False                True                        False
# 4                 False                True                         True
#
# ...

# %%
df.rename(columns={
    'facility_name': 'School_name',
    'facility_type_display': 'School_type',
    'improved_water_supply': 'Improved_water_supply',
    'improved_sanitation': 'Improved_sanitation',
    'chalkboard_each_classroom_yn': 'Chalkboard_in_classroom',
    'num_tchrs_with_nce': 'Nce_qualified_teachers',
    'num_tchr_full_time': 'Full_time_teachers',
    'num_students_total': 'Total_students',
    'num_classrms_total': 'Total_classrooms',
    'phcn_electricity': 'Electricity_access',
    'num_toilets_total': 'Total_toilets',
    'num_students_male': 'Male_students',
    'num_students_female': 'Female_students',
    'num_tchrs_male': 'Male_teachers',	
    'num_tchrs_female':	'Female_teachers',
    'date_of_survey': 'Survey_date',
    'education_type': 'Education_type',	
    'community': 'Community',	
    'ward': 'Ward',	
    'management': 'Management_type',	
    'sector': 'Sector',	
    'unique_lga': 'Unique_lga',	
    'latitude': 'Latitude',	
    'longitude': 'Longitude'
    
}, inplace=True)
df.head()
# Out:
#                    School_name                                   School_type  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
#
#   Improved_water_supply Improved_sanitation Chalkboard_in_classroom  \
# 0                  True                True                   False
# 1                 False               False                     NaN
# 2                  True                True                   False
# 3                 False                True                   False
# 4                 False                True                    True
#
#    Nce_qualified_teachers  Full_time_teachers  Total_students  \
# ...

# %%
df.dropna(subset=['School_name'], inplace=True)
df['School_name'].isna().sum()
# Out:
# np.int64(0)

# %%
df.dropna(subset=['Unique_lga'], inplace=True)
df['Unique_lga'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# School_name                   0
# School_type                 764
# Improved_water_supply       139
# Improved_sanitation         157
# Chalkboard_in_classroom    2009
# Nce_qualified_teachers     3374
# Full_time_teachers         2161
# Total_students             5078
# Total_classrooms           3119
# Electricity_access          137
# Total_toilets              2814
# Male_students              4213
# Female_students            4184
# Male_teachers              3516
# Female_teachers            3155
# Survey_date                   0
# Education_type               81
# Community                    91
# Ward                        625
# Management_type            1073
# Sector                        0
# Unique_lga                    0
# Latitude                      0
# Longitude                     0
# dtype: int64

# %%
bool_cols = ['Improved_water_supply', 'Improved_sanitation', 'Chalkboard_in_classroom', 'Electricity_access']
for col in bool_cols:
    df[col] = df[col].astype(str).str.strip().str.lower()

# %%
df.head()
# Out:
#                    School_name                                   School_type  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
#
#   Improved_water_supply Improved_sanitation Chalkboard_in_classroom  \
# 0                  true                true                   false
# 1                 false               false                     NaN
# 2                  true                true                   false
# 3                 false                true                   false
# 4                 false                true                    true
#
#    Nce_qualified_teachers  Full_time_teachers  Total_students  \
# ...

# %%
for col in bool_cols:
    df[col] = df[col].fillna(df[col].mode())
df[bool_cols].dtypes
# Out:
# Improved_water_supply      str
# Improved_sanitation        str
# Chalkboard_in_classroom    str
# Electricity_access         str
# dtype: object

# %%
bool_cols = ['Improved_water_supply', 'Improved_sanitation', 'Chalkboard_in_classroom', 'Electricity_access']
for col in bool_cols:
    df[col] = df[col].map({'true': True, 'false': False})
    df[col] = df[col].astype(bool)

# %%
df[bool_cols].dtypes
# Out:
# Improved_water_supply      bool
# Improved_sanitation        bool
# Chalkboard_in_classroom    bool
# Electricity_access         bool
# dtype: object

# %%
df.head()
# Out:
#                    School_name                                   School_type  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
#
#    Improved_water_supply  Improved_sanitation  Chalkboard_in_classroom  \
# 0                   True                 True                    False
# 1                  False                False                     True
# 2                   True                 True                    False
# 3                  False                 True                    False
# 4                  False                 True                     True
#
#    Nce_qualified_teachers  Full_time_teachers  Total_students  \
# ...

# %%
catg_cols = ['School_type', 'Education_type', 'Community', 'Ward', 'Management_type']
for col in catg_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
num_cols = ['Nce_qualified_teachers', 'Full_time_teachers', 'Total_students', 'Total_classrooms', 'Total_toilets', 'Male_students',
            'Female_students', 'Male_teachers', 'Female_teachers']
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isna().sum()
# Out:
# School_name                0
# School_type                0
# Improved_water_supply      0
# Improved_sanitation        0
# Chalkboard_in_classroom    0
# Nce_qualified_teachers     0
# Full_time_teachers         0
# Total_students             0
# Total_classrooms           0
# Electricity_access         0
# Total_toilets              0
# Male_students              0
# Female_students            0
# Male_teachers              0
# Female_teachers            0
# Survey_date                0
# Education_type             0
# Community                  0
# Ward                       0
# Management_type            0
# Sector                     0
# Unique_lga                 0
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
df.head()
# Out:
#                    School_name                                   School_type  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
#
#    Improved_water_supply  Improved_sanitation  Chalkboard_in_classroom  \
# 0                   True                 True                    False
# 1                  False                False                     True
# 2                   True                 True                    False
# 3                  False                 True                    False
# 4                  False                 True                     True
#
#    Nce_qualified_teachers  Full_time_teachers  Total_students  \
# ...

# %%
from dateutil import parser
def date_parser(date_str):
    try:
        return parser.parse(date_str, dayfirst=True)
    except Exception:
        return pd.NaT
df['Survey_date'] = df['Survey_date'].apply(date_parser)

df['Survey_date']
# Out:
# 0       2014-03-04
# 1       2014-05-02
# 2       2014-05-02
# 3       2014-04-25
# 4       2014-04-25
#            ...
# 98662   2014-04-09
# 98663   2014-04-13
# 98664   2014-05-02
# 98665   2014-05-21
# 98666   2014-04-17
# Name: Survey_date, Length: 98398, dtype: datetime64[us]

# %%
df['School_type'] = df['School_type'].astype(str).str.strip().str.lower()

# %%
df['School_type'].value_counts()
# Out:
# School_type
# primary only                                            28994
# pre-primary and primary                                 18832
# primary school only                                     15152
# pre-primary and primary school combined                 10838
# junior secondary only                                    5270
# junior and senior secondary                              5211
# junior and senior secondary school combined              4122
# junior secondary school only                             1922
# pre-primary only                                         1897
# senior secondary only                                    1476
# primary, junior, and senior secondary                     967
# primary and junior secondary                              944
# primary and junior secondary school combined              910
# information not available / don't know                    797
# primary, junior and senior secondary school combined      763
# ...

# %%
df['School_type'] = df['School_type'].replace({
    'primary only': 'primary school only',
    'pre-primary and primary': 'pre-primary and primary school combined',
    'junior secondary only': 'junior secondary school only',
    'junior and senior secondary': 'junior and senior secondary school combined',
    'primary, junior, and senior secondary': 'primary, junior and senior secondary school combined',
    'primary and junior secondary': 'primary and junior secondary school combined'
})
df['School_type'].value_counts()
# Out:
# School_type
# primary school only                                     44146
# pre-primary and primary school combined                 29670
# junior and senior secondary school combined              9333
# junior secondary school only                             7192
# pre-primary only                                         1897
# primary and junior secondary school combined             1854
# primary, junior and senior secondary school combined     1730
# senior secondary only                                    1476
# information not available / don't know                    797
# adult, vocational, or technical                           303
# Name: count, dtype: int64

# %%
df = df[df['School_type'] != "information not available / don't know"]
df['School_type'].value_counts()
# Out:
# School_type
# primary school only                                     44146
# pre-primary and primary school combined                 29670
# junior and senior secondary school combined              9333
# junior secondary school only                             7192
# pre-primary only                                         1897
# primary and junior secondary school combined             1854
# primary, junior and senior secondary school combined     1730
# senior secondary only                                    1476
# adult, vocational, or technical                           303
# Name: count, dtype: int64

# %%
df['Education_type'].value_counts()
# Out:
# Education_type
# Formal Only       58563
# formal_only       31997
# Integrated         3988
# integrated         1650
# religious_only      716
# Religious Only      648
# dk                   39
# Name: count, dtype: int64

# %%
df['Education_type'] = df['Education_type'].astype(str).str.strip().str.lower()
df['Education_type'].value_counts()
# Out:
# Education_type
# formal only       58563
# formal_only       31997
# integrated         5638
# religious_only      716
# religious only      648
# dk                   39
# Name: count, dtype: int64

# %%
df['Education_type'] = df['Education_type'].replace({
    'formal only': 'formal_only',
    'religious only': 'religious_only'
})

# %%
df['Education_type'] = df['Education_type']. replace('dk', df['Education_type'].mode()[0])
df['Education_type'].value_counts()
# Out:
# Education_type
# formal_only       90599
# integrated         5638
# religious_only     1364
# Name: count, dtype: int64

# %%
df['Management_type'].value_counts()
# Out:
# Management_type
# public         75570
# private        20563
# faith_based     1451
# none              17
# Name: count, dtype: int64

# %%
df = df[df['Management_type'].str.strip().str.lower() != "none"]
df['Management_type'].value_counts()
# Out:
# Management_type
# public         75570
# private        20563
# faith_based     1451
# Name: count, dtype: int64

# %%
df['Unique_lga'] = df['Unique_lga'].astype(str).str.strip().str.lower()
df['Unique_lga'].value_counts()
# Out:
# Unique_lga
# ogun_ifo               565
# kaduna_chikun          432
# kaduna_kachia          331
# benue_buruku           328
# delta_uvwie            328
#                       ...
# borno_marte             14
# yobe_yusufari           12
# cross_river_bakassi     10
# borno_ngala              6
# borno_kwaya_kusar        3
# Name: count, Length: 772, dtype: int64

# %%
df.dtypes
# Out:
# School_name                           str
# School_type                           str
# Improved_water_supply                bool
# Improved_sanitation                  bool
# Chalkboard_in_classroom              bool
# Nce_qualified_teachers            float64
# Full_time_teachers                float64
# Total_students                    float64
# Total_classrooms                  float64
# Electricity_access                   bool
# Total_toilets                     float64
# Male_students                     float64
# Female_students                   float64
# Male_teachers                     float64
# Female_teachers                   float64
# Survey_date                datetime64[us]
# Education_type                        str
# Community                             str
# Ward                                  str
# Management_type                       str
# Sector                                str
# Unique_lga                            str
# ...

# %%
df['Total_teachers'] = df['Male_teachers'] + df['Female_teachers']
df.head()
# Out:
#                    School_name                                   School_type  \
# 0                    CPS SWALI                           primary school only
# 1           NANA Basic Academy  primary and junior secondary school combined
# 2  L.E.A Primary School Pabeyi                           primary school only
# 3   L.E.A.PrimarySchoolPagadna                           primary school only
# 4              Syflora Academy                           primary school only
#
#    Improved_water_supply  Improved_sanitation  Chalkboard_in_classroom  \
# 0                   True                 True                    False
# 1                  False                False                     True
# 2                   True                 True                    False
# 3                  False                 True                    False
# 4                  False                 True                     True
#
#    Nce_qualified_teachers  Full_time_teachers  Total_students  \
# ...

# %%
df['Expected_total'] = df['Male_students'] + df['Female_students']

# %%
(df['Expected_total'] != df['Total_students']).sum()
# Out:
# np.int64(5376)

# %%
df['Total_students'] = df['Male_students'] + df['Female_students']
df.head()
# Out:
#                    School_name                                   School_type  \
# 0                    CPS SWALI                           primary school only
# 1           NANA Basic Academy  primary and junior secondary school combined
# 2  L.E.A Primary School Pabeyi                           primary school only
# 3   L.E.A.PrimarySchoolPagadna                           primary school only
# 4              Syflora Academy                           primary school only
#
#    Improved_water_supply  Improved_sanitation  Chalkboard_in_classroom  \
# 0                   True                 True                    False
# 1                  False                False                     True
# 2                   True                 True                    False
# 3                  False                 True                    False
# 4                  False                 True                     True
#
#    Nce_qualified_teachers  Full_time_teachers  Total_students  \
# ...

# %%
(df['Expected_total'] != df['Total_students']).sum()
# Out:
# np.int64(0)

# %%
student_ratio = df['Total_students'] / df['Total_teachers']
df['Student_to_teacher_ratio'] = round(student_ratio, 0)
df.head()
# Out:
#                    School_name                                   School_type  \
# 0                    CPS SWALI                           primary school only
# 1           NANA Basic Academy  primary and junior secondary school combined
# 2  L.E.A Primary School Pabeyi                           primary school only
# 3   L.E.A.PrimarySchoolPagadna                           primary school only
# 4              Syflora Academy                           primary school only
#
#    Improved_water_supply  Improved_sanitation  Chalkboard_in_classroom  \
# 0                   True                 True                    False
# 1                  False                False                     True
# 2                   True                 True                    False
# 3                  False                 True                    False
# 4                  False                 True                     True
#
#    Nce_qualified_teachers  Full_time_teachers  Total_students  \
# ...

# %%
most_common = df['School_type'].mode()[0]
print("Most common educational facility:", most_common)
# Out:
# Most common educational facility: primary school only

# %%
Total_schools = len(df)

water_supply_pct = df['Improved_water_supply'].sum() / Total_schools * 100
sanitation_pct = df['Improved_sanitation'].sum() / Total_schools * 100
electricity_pct = df['Electricity_access'].sum() / Total_schools * 100

print(f"Percentage of Schools that have improved water supply: {water_supply_pct:.2f}%")
print(f"Percentage of Schools that have improved sanitation: {sanitation_pct:.2f}%")
print(f"Percentage of Schools that have electricity access: {electricity_pct:.2f}%")
# Out:
# Percentage of Schools that have improved water supply: 38.18%
# Percentage of Schools that have improved sanitation: 46.28%
# Percentage of Schools that have electricity access: 25.13%

# %%
Total_student = df['Total_students'].sum()
Total_school = len(df)
Average_student = Total_student / Total_school
print(f"Average number of students per school: {Average_student:.2f}")
# Out:
# Average number of students per school: 351.80

# %%
Total_teacher = df['Total_teachers'].sum()
Total_school = len(df)
Average_teacher = Total_teacher / Total_school
print(f"Average number of teacher per school: {Average_teacher:.2f}")
# Out:
# Average number of teacher per school: 11.52

# %%
Stud_pop_by_management_type = df.groupby('Management_type')['Total_students'].sum()
print(Stud_pop_by_management_type)
# Out:
# Management_type
# faith_based      432904.0
# private         4593750.0
# public         29302935.0
# Name: Total_students, dtype: float64

# %%
Total_student = df['Total_students'].sum()
Stud_pop_by_management_type_pct = Stud_pop_by_management_type / Total_student *100
print(Stud_pop_by_management_type_pct)
# Out:
# Management_type
# faith_based     1.261023
# private        13.381314
# public         85.357663
# Name: Total_students, dtype: float64

# %%
Teacher_count_by_mangement_type = df.groupby('Management_type')['Total_teachers'].sum()
print(Teacher_count_by_mangement_type)
# Out:
# Management_type
# faith_based     20683.0
# private        262435.0
# public         840723.0
# Name: Total_teachers, dtype: float64

# %%
Total_teacher = df['Total_teachers'].sum()
Teacher_count_by_management_type_pct = Teacher_count_by_mangement_type / Total_teacher *100
print(Teacher_count_by_management_type_pct)
# Out:
# Management_type
# faith_based     1.840385
# private        23.351613
# public         74.808002
# Name: Total_teachers, dtype: float64

# %%
Infrastructure = ['Electricity_access','Improved_water_supply','Improved_sanitation']

df.groupby('Management_type')[Infrastructure].mean()*100
# Out:
#                  Electricity_access  Improved_water_supply  \
# Management_type
# faith_based               52.860096              64.782908
# private                   51.806643              57.233867
# public                    17.336245              32.481143
#
#                  Improved_sanitation
# Management_type
# faith_based                74.500345
# private                    71.516802
# public                     38.864629

# %%
df.groupby('Unique_lga')['School_name'].count().sort_values(ascending=False)
# Out:
# Unique_lga
# ogun_ifo               565
# kaduna_chikun          432
# kaduna_kachia          331
# delta_uvwie            328
# benue_buruku           328
#                       ...
# borno_marte             14
# yobe_yusufari           12
# cross_river_bakassi     10
# borno_ngala              6
# borno_kwaya_kusar        3
# Name: School_name, Length: 772, dtype: int64

# %%
lga_access = df.groupby('Unique_lga')[['Electricity_access', 'Improved_water_supply', 'Improved_sanitation']].mean()*100

lga_access.sort_values(['Electricity_access', 'Improved_water_supply', 'Improved_sanitation']).head(5)
# Out:
#                  Electricity_access  Improved_water_supply  \
# Unique_lga
# kogi_ibaji                      0.0               1.149425
# borno_guzamala                  0.0               6.666667
# taraba_sardauna                 0.0               7.075472
# kogi_bassa                      0.0               8.219178
# adamawa_teungo                  0.0               9.677419
#
#                  Improved_sanitation
# Unique_lga
# kogi_ibaji                 11.494253
# borno_guzamala             26.666667
# taraba_sardauna            46.226415
# kogi_bassa                 15.068493
# adamawa_teungo             27.956989

# %%
School_counts = df['School_type'].value_counts().reset_index()
School_counts.columns = ['School_type', 'Count']
fig = px.bar(
    School_counts,
    x='School_type',
    y='Count',
    title='Distribution of school type',
    text_auto=True,
    height=600
)
fig.show()

# %%
fig = px.histogram(
    df,
    x='Total_students',
    nbins=30,
    title='Distribution of Student Population (Log_scale)'
)

fig.show()

# %%
fig=px.box(
    df,
    y='Total_teachers',
    title='Box Plot of Teacher Distribution',
    height=800
)
fig.show()

# %%
fig=px.pie(
    df,
    names='Electricity_access',
    values='
)
